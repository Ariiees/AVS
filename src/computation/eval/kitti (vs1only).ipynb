# %% [markdown]
# # KISS-ICP running on the KITTI-Odometry benchmark dataset
#
# The whole purpose of this notebook is to have a reproducable entry point for the experiments of the paper. You can also modify the system and just run this notebook to inspect the overall results
#
# ## Expected dataset layout
#
# ```
# <data/kitti-odometry/dataset>
# ├── poses
# │   ├── 00.txt
# │   ├── 01.txt
# │   ├── 02.txt
# │   ├── 03.txt
# │   ├── 04.txt
# │   ├── 05.txt
# │   ├── 06.txt
# │   ├── 07.txt
# │   ├── 08.txt
# │   ├── 09.txt
# │   ├── 10.txt
# └── sequences
#     ├── 00
#     │   ├── calib.txt
#     │   ├── poses.txt
#     │   ├── times.txt
#     │   └── velodyne
#     ├── 01
#     │   ├── ....
#
# ```

# %%
# Install KISS-ICP and Plotting tools
# %pip install kiss-icp ipympl evo >/dev/null

import os

import kiss_icp
import matplotlib.pyplot as plt
import numpy as np
from evo.tools import plot
from kiss_icp.datasets import dataset_factory
from kiss_icp.pipeline import OdometryPipeline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib widget
# Out:
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_root = os.environ.get("DATASETS")
kitti_root = os.path.join(data_root, "kitti-odometry/dataset")
print(f"Reading datasets from : {data_root}")
# Out:
# Reading datasets from : /home/yuxw/Downloads/data

# %% [markdown]
# ## Run all sequences on the dataset

# %%
from kiss_icp_eval import run_sequence


def kitti_sequence(sequence: int):
    return OdometryPipeline(
        dataset=dataset_factory(
            dataloader="kitti",
            data_dir=kitti_root,
            sequence=sequence,
        )
    )


results = {}
for sequence in range(0, 11):
    run_sequence(kitti_sequence, sequence=sequence, results=results)
# Out:
# Now evaluating sequence 00
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.603   %
#          Average Rotational Error   0.003   deg/m
#   Absolute Trajectory Error (ATE)   5.038   m
#   Absolute Rotational Error (ARE)   0.024   rad
#                 Average Frequency    149    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 01
#   0%|                                                                                                         …
#  ──────────────────────────────────────────────────
#                            Metric   Value    Units
#  ──────────────────────────────────────────────────
#         Average Translation Error   1.053    %
#          Average Rotational Error   0.002    deg/m
#   Absolute Trajectory Error (ATE)   10.537   m
#   Absolute Rotational Error (ARE)   0.036    rad
#                 Average Frequency     62     Hz
#                   Average Runtime     16     ms
#  ──────────────────────────────────────────────────
# Now evaluating sequence 02
#   0%|                                                                                                         …
#  ───────────────────────────────────────────────────
#                            Metric    Value    Units
#  ───────────────────────────────────────────────────
#         Average Translation Error   26.229    %
#          Average Rotational Error    0.102    deg/m
#   Absolute Trajectory Error (ATE)   229.604   m
#   Absolute Rotational Error (ARE)    0.928    rad
#                 Average Frequency     66      Hz
#                   Average Runtime     15      ms
#  ───────────────────────────────────────────────────
# Now evaluating sequence 03
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.876   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.935   m
#   Absolute Rotational Error (ARE)   0.009   rad
#                 Average Frequency    89     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 04
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.346   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.288   m
#   Absolute Rotational Error (ARE)   0.753   rad
#                 Average Frequency    90     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 05
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.511   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   3.304   m
#   Absolute Rotational Error (ARE)   0.021   rad
#                 Average Frequency    153    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 06
#   0%|                                                                                                         …
#  ──────────────────────────────────────────────────
#                            Metric   Value    Units
#  ──────────────────────────────────────────────────
#         Average Translation Error   14.909   %
#          Average Rotational Error   0.002    deg/m
#   Absolute Trajectory Error (ATE)   71.799   m
#   Absolute Rotational Error (ARE)   0.016    rad
#                 Average Frequency     55     Hz
#                   Average Runtime     18     ms
#  ──────────────────────────────────────────────────
# Now evaluating sequence 07
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.428   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.528   m
#   Absolute Rotational Error (ARE)   0.008   rad
#                 Average Frequency    166    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 08
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.909   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   3.386   m
#   Absolute Rotational Error (ARE)   0.025   rad
#                 Average Frequency    107    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 09
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.686   %
#          Average Rotational Error   0.003   deg/m
#   Absolute Trajectory Error (ATE)   2.811   m
#   Absolute Rotational Error (ARE)   0.025   rad
#                 Average Frequency    99     Hz
#                   Average Runtime    11     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 10
#   0%|                                                                                                         …
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.776   %
#          Average Rotational Error   0.003   deg/m
#   Absolute Trajectory Error (ATE)   1.288   m
#   Absolute Rotational Error (ARE)   0.012   rad
#                 Average Frequency    153    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────

# %%
from kiss_icp_eval import print_metrics_table

print_metrics_table(results)
# Out:
# # Experiment Results
# |Metric|Value|Units|
# |-:|:-:|:-|
# Average Translation Error| 4.3024|% |
# Average Rotational Error| 0.0114|deg/m |
# Absolute Trajectory Error (ATE)| 29.9562|m |
# Absolute Rotational Error (ARE)| 0.1689|rad |
# Average Frequency| 108.0909|Hz |
# Average Runtime| 11.0909|ms |

# %% [markdown]
# ## Trajectories Results

# %%
from kiss_icp_eval import plot_trajectories

plot_trajectories(results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
