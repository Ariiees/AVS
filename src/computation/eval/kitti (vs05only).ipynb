# %% [markdown]
# # KISS-ICP running on the KITTI-Odometry benchmark dataset
#
# The whole purpose of this notebook is to have a reproducable entry point for the experiments of the paper. You can also modify the system and just run this notebook to inspect the overall results
#
# ## Expected dataset layout
#
# ```
# <data/kitti-odometry/dataset>
# ├── poses
# │   ├── 00.txt
# │   ├── 01.txt
# │   ├── 02.txt
# │   ├── 03.txt
# │   ├── 04.txt
# │   ├── 05.txt
# │   ├── 06.txt
# │   ├── 07.txt
# │   ├── 08.txt
# │   ├── 09.txt
# │   ├── 10.txt
# └── sequences
#     ├── 00
#     │   ├── calib.txt
#     │   ├── poses.txt
#     │   ├── times.txt
#     │   └── velodyne
#     ├── 01
#     │   ├── ....
#
# ```

# %%
# Install KISS-ICP and Plotting tools
# %pip install kiss-icp ipympl evo >/dev/null

import os

import kiss_icp
import matplotlib.pyplot as plt
import numpy as np
from evo.tools import plot
from kiss_icp.datasets import dataset_factory
from kiss_icp.pipeline import OdometryPipeline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib widget
# Out:
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %%
data_root = os.environ.get("DATASETS")
kitti_root = os.path.join(data_root, "kitti-odometry/dataset")
print(f"Reading datasets from : {data_root}")
# Out:
# Reading datasets from : /home/yuxw/Downloads/data

# %% [markdown]
# ## Run all sequences on the dataset

# %%
from kiss_icp_eval import run_sequence


def kitti_sequence(sequence: int):
    return OdometryPipeline(
        dataset=dataset_factory(
            dataloader="kitti",
            data_dir=kitti_root,
            sequence=sequence,
        )
    )


results = {}
for sequence in range(0, 11):
    run_sequence(kitti_sequence, sequence=sequence, results=results)
# Out:
# Now evaluating sequence 00
#   0%|                                                                                   | 0/4541 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.511   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   4.329   m
#   Absolute Rotational Error (ARE)   0.022   rad
#                 Average Frequency    128    Hz
#                   Average Runtime     8     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 01
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.642   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   3.687   m
#   Absolute Rotational Error (ARE)   0.019   rad
#                 Average Frequency    60     Hz
#                   Average Runtime    17     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 02
#   0%|                                                                                   | 0/4661 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.518   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   8.245   m
#   Absolute Rotational Error (ARE)   0.031   rad
#                 Average Frequency    106    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 03
#   0%|                                                                                    | 0/801 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.694   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.531   m
#   Absolute Rotational Error (ARE)   0.009   rad
#                 Average Frequency    77     Hz
#                   Average Runtime    13     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 04
#   0%|                                                                                    | 0/271 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.313   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.249   m
#   Absolute Rotational Error (ARE)   0.625   rad
#                 Average Frequency    83     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 05
#   0%|                                                                                   | 0/2761 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.320   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   1.944   m
#   Absolute Rotational Error (ARE)   0.013   rad
#                 Average Frequency    118    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 06
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.274   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   0.624   m
#   Absolute Rotational Error (ARE)   0.007   rad
#                 Average Frequency    73     Hz
#                   Average Runtime    14     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 07
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.342   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.388   m
#   Absolute Rotational Error (ARE)   0.007   rad
#                 Average Frequency    136    Hz
#                   Average Runtime     8     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 08
#   0%|                                                                                   | 0/4071 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.802   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   2.533   m
#   Absolute Rotational Error (ARE)   0.020   rad
#                 Average Frequency    89     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 09
#   0%|                                                                                   | 0/1591 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.501   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   1.683   m
#   Absolute Rotational Error (ARE)   0.016   rad
#                 Average Frequency    83     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 10
#   0%|                                                                                   | 0/1201 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.546   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.837   m
#   Absolute Rotational Error (ARE)   0.010   rad
#                 Average Frequency    127    Hz
#                   Average Runtime     8     ms
#  ─────────────────────────────────────────────────

# %%
from kiss_icp_eval import print_metrics_table

print_metrics_table(results)
# Out:
# # Experiment Results
# |Metric|Value|Units|
# |-:|:-:|:-|
# Average Translation Error| 0.4966|% |
# Average Rotational Error| 0.0016|deg/m |
# Absolute Trajectory Error (ATE)| 2.2773|m |
# Absolute Rotational Error (ARE)| 0.0708|rad |
# Average Frequency| 98.1818|Hz |
# Average Runtime| 11.1818|ms |

# %% [markdown]
# ## Trajectories Results

# %%
from kiss_icp_eval import plot_trajectories

plot_trajectories(results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
