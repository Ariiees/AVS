# %% [markdown]
# # KISS-ICP running on the KITTI-Odometry benchmark dataset
#
# The whole purpose of this notebook is to have a reproducable entry point for the experiments of the paper. You can also modify the system and just run this notebook to inspect the overall results
#
# ## Expected dataset layout
#
# ```
# <data/kitti-odometry/dataset>
# ├── poses
# │   ├── 00.txt
# │   ├── 01.txt
# │   ├── 02.txt
# │   ├── 03.txt
# │   ├── 04.txt
# │   ├── 05.txt
# │   ├── 06.txt
# │   ├── 07.txt
# │   ├── 08.txt
# │   ├── 09.txt
# │   ├── 10.txt
# └── sequences
#     ├── 00
#     │   ├── calib.txt
#     │   ├── poses.txt
#     │   ├── times.txt
#     │   └── velodyne
#     ├── 01
#     │   ├── ....
#
# ```

# %%
# Install KISS-ICP and Plotting tools
# %pip install kiss-icp ipympl evo >/dev/null

import os

import kiss_icp
import matplotlib.pyplot as plt
import numpy as np
from evo.tools import plot
from kiss_icp.datasets import dataset_factory
from kiss_icp.pipeline import OdometryPipeline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib widget
# Out:
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %%
data_root = os.environ.get("DATASETS")
kitti_root = os.path.join(data_root, "kitti-odometry/dataset")
print(f"Reading datasets from : {data_root}")
# Out:
# Reading datasets from : /home/yuxw/Downloads/data

# %% [markdown]
# ## Run all sequences on the dataset

# %%
from kiss_icp_eval import run_sequence


def kitti_sequence(sequence: int):
    return OdometryPipeline(
        dataset=dataset_factory(
            dataloader="kitti",
            data_dir=kitti_root,
            sequence=sequence,
        )
    )


results = {}
for sequence in range(0, 11):
    run_sequence(kitti_sequence, sequence=sequence, results=results)
# Out:
# Now evaluating sequence 00
#   0%|                                             | 0/4541 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.530   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   3.298   m
#   Absolute Rotational Error (ARE)   0.017   rad
#                 Average Frequency    121    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 01
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.674   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   3.127   m
#   Absolute Rotational Error (ARE)   0.017   rad
#                 Average Frequency    58     Hz
#                   Average Runtime    18     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 02
#   0%|                                             | 0/4661 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.505   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   5.773   m
#   Absolute Rotational Error (ARE)   0.023   rad
#                 Average Frequency    100    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 03
#   0%|                                              | 0/801 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.742   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.537   m
#   Absolute Rotational Error (ARE)   0.009   rad
#                 Average Frequency    72     Hz
#                   Average Runtime    14     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 04
#   0%|                                              | 0/271 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.348   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   0.224   m
#   Absolute Rotational Error (ARE)   0.478   rad
#                 Average Frequency    76     Hz
#                   Average Runtime    14     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 05
#   0%|                                             | 0/2761 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.335   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   1.597   m
#   Absolute Rotational Error (ARE)   0.011   rad
#                 Average Frequency    105    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 06
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.285   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   0.455   m
#   Absolute Rotational Error (ARE)   0.006   rad
#                 Average Frequency    71     Hz
#                   Average Runtime    14     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 07
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.364   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.337   m
#   Absolute Rotational Error (ARE)   0.007   rad
#                 Average Frequency    124    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 08
#   0%|                                             | 0/4071 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.822   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   2.021   m
#   Absolute Rotational Error (ARE)   0.016   rad
#                 Average Frequency    81     Hz
#                   Average Runtime    13     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 09
#   0%|                                             | 0/1591 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.550   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   1.340   m
#   Absolute Rotational Error (ARE)   0.015   rad
#                 Average Frequency    77     Hz
#                   Average Runtime    13     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 10
#   0%|                                             | 0/1201 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.485   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.746   m
#   Absolute Rotational Error (ARE)   0.009   rad
#                 Average Frequency    112    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────

# %%
from kiss_icp_eval import print_metrics_table

print_metrics_table(results)
# Out:
# # Experiment Results
# |Metric|Value|Units|
# |-:|:-:|:-|
# Average Translation Error| 0.5127|% |
# Average Rotational Error| 0.0014|deg/m |
# Absolute Trajectory Error (ATE)| 1.7686|m |
# Absolute Rotational Error (ARE)| 0.0552|rad |
# Average Frequency| 90.6364|Hz |
# Average Runtime| 12.0909|ms |

# %% [markdown]
# ## Trajectories Results

# %%
from kiss_icp_eval import plot_trajectories

plot_trajectories(results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
