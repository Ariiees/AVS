# %% [markdown]
# # KISS-ICP running on the KITTI-Odometry benchmark dataset
#
# The whole purpose of this notebook is to have a reproducable entry point for the experiments of the paper. You can also modify the system and just run this notebook to inspect the overall results
#
# ## Expected dataset layout
#
# ```
# <data/kitti-odometry/dataset>
# ├── poses
# │   ├── 00.txt
# │   ├── 01.txt
# │   ├── 02.txt
# │   ├── 03.txt
# │   ├── 04.txt
# │   ├── 05.txt
# │   ├── 06.txt
# │   ├── 07.txt
# │   ├── 08.txt
# │   ├── 09.txt
# │   ├── 10.txt
# └── sequences
#     ├── 00
#     │   ├── calib.txt
#     │   ├── poses.txt
#     │   ├── times.txt
#     │   └── velodyne
#     ├── 01
#     │   ├── ....
#
# ```

# %%
# Install KISS-ICP and Plotting tools
# %pip install kiss-icp ipympl evo >/dev/null

import os

import kiss_icp
import matplotlib.pyplot as plt
import numpy as np
from evo.tools import plot
from kiss_icp.datasets import dataset_factory
from kiss_icp.pipeline import OdometryPipeline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib widget
# Out:
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %%
data_root = os.environ.get("DATASETS")
kitti_root = os.path.join(data_root, "kitti-odometry/dataset")
print(f"Reading datasets from : {data_root}")
# Out:
# Reading datasets from : /home/yuxw/Downloads/data

# %% [markdown]
# ## Run all sequences on the dataset

# %%
from kiss_icp_eval import run_sequence


def kitti_sequence(sequence: int):
    return OdometryPipeline(
        dataset=dataset_factory(
            dataloader="kitti",
            data_dir=kitti_root,
            sequence=sequence,
        )
    )


results = {}
for sequence in range(0, 11):
    run_sequence(kitti_sequence, sequence=sequence, results=results)
# Out:
# Now evaluating sequence 00
#   0%|                                             | 0/4541 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.049   %
#          Average Rotational Error   0.005   deg/m
#   Absolute Trajectory Error (ATE)   3.990   m
#   Absolute Rotational Error (ARE)   0.030   rad
#                 Average Frequency    181    Hz
#                   Average Runtime     6     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 01
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.271   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   6.194   m
#   Absolute Rotational Error (ARE)   0.020   rad
#                 Average Frequency    93     Hz
#                   Average Runtime    11     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 02
#   0%|                                             | 0/4661 [00:00<?, ? frames/s]
#  ──────────────────────────────────────────────────
#                            Metric   Value    Units
#  ──────────────────────────────────────────────────
#         Average Translation Error   1.866    %
#          Average Rotational Error   0.007    deg/m
#   Absolute Trajectory Error (ATE)   15.493   m
#   Absolute Rotational Error (ARE)   0.077    rad
#                 Average Frequency    158     Hz
#                   Average Runtime     7      ms
#  ──────────────────────────────────────────────────
# Now evaluating sequence 03
#   0%|                                              | 0/801 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.169   %
#          Average Rotational Error   0.003   deg/m
#   Absolute Trajectory Error (ATE)   0.721   m
#   Absolute Rotational Error (ARE)   0.029   rad
#                 Average Frequency    117    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 04
#   0%|                                              | 0/271 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.576   %
#          Average Rotational Error   0.004   deg/m
#   Absolute Trajectory Error (ATE)   0.358   m
#   Absolute Rotational Error (ARE)   0.404   rad
#                 Average Frequency    107    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 05
#   0%|                                             | 0/2761 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.622   %
#          Average Rotational Error   0.004   deg/m
#   Absolute Trajectory Error (ATE)   3.474   m
#   Absolute Rotational Error (ARE)   0.023   rad
#                 Average Frequency    144    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 06
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.371   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.526   m
#   Absolute Rotational Error (ARE)   0.017   rad
#                 Average Frequency    99     Hz
#                   Average Runtime    11     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 07
#   0%|                                             | 0/1101 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.576   %
#          Average Rotational Error   0.004   deg/m
#   Absolute Trajectory Error (ATE)   0.410   m
#   Absolute Rotational Error (ARE)   0.013   rad
#                 Average Frequency    184    Hz
#                   Average Runtime     6     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 08
#   0%|                                             | 0/4071 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.130   %
#          Average Rotational Error   0.004   deg/m
#   Absolute Trajectory Error (ATE)   2.620   m
#   Absolute Rotational Error (ARE)   0.032   rad
#                 Average Frequency    121    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 09
#   0%|                                             | 0/1591 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.194   %
#          Average Rotational Error   0.004   deg/m
#   Absolute Trajectory Error (ATE)   2.021   m
#   Absolute Rotational Error (ARE)   0.027   rad
#                 Average Frequency    126    Hz
#                   Average Runtime     8     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 10
#   0%|                                             | 0/1201 [00:00<?, ? frames/s]
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   1.536   %
#          Average Rotational Error   0.007   deg/m
#   Absolute Trajectory Error (ATE)   1.624   m
#   Absolute Rotational Error (ARE)   0.028   rad
#                 Average Frequency    145    Hz
#                   Average Runtime     7     ms
#  ─────────────────────────────────────────────────

# %%
from kiss_icp_eval import print_metrics_table

print_metrics_table(results)
# Out:
# # Experiment Results
# |Metric|Value|Units|
# |-:|:-:|:-|
# Average Translation Error| 1.0330|% |
# Average Rotational Error| 0.0040|deg/m |
# Absolute Trajectory Error (ATE)| 3.4028|m |
# Absolute Rotational Error (ARE)| 0.0638|rad |
# Average Frequency| 134.0909|Hz |
# Average Runtime| 8.2727|ms |

# %% [markdown]
# ## Trajectories Results

# %%
from kiss_icp_eval import plot_trajectories

plot_trajectories(results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
