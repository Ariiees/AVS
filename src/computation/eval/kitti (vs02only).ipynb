# %% [markdown]
# # KISS-ICP running on the KITTI-Odometry benchmark dataset
#
# The whole purpose of this notebook is to have a reproducable entry point for the experiments of the paper. You can also modify the system and just run this notebook to inspect the overall results
#
# ## Expected dataset layout
#
# ```
# <data/kitti-odometry/dataset>
# ├── poses
# │   ├── 00.txt
# │   ├── 01.txt
# │   ├── 02.txt
# │   ├── 03.txt
# │   ├── 04.txt
# │   ├── 05.txt
# │   ├── 06.txt
# │   ├── 07.txt
# │   ├── 08.txt
# │   ├── 09.txt
# │   ├── 10.txt
# └── sequences
#     ├── 00
#     │   ├── calib.txt
#     │   ├── poses.txt
#     │   ├── times.txt
#     │   └── velodyne
#     ├── 01
#     │   ├── ....
#
# ```

# %%
# Install KISS-ICP and Plotting tools
# %pip install kiss-icp ipympl evo >/dev/null

import os

import kiss_icp
import matplotlib.pyplot as plt
import numpy as np
from evo.tools import plot
from kiss_icp.datasets import dataset_factory
from kiss_icp.pipeline import OdometryPipeline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib widget
# Out:
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %%
data_root = os.environ.get("DATASETS")
kitti_root = os.path.join(data_root, "kitti-odometry/dataset")
print(f"Reading datasets from : {data_root}")
# Out:
# Reading datasets from : /home/yuxw/Downloads/data

# %% [markdown]
# ## Run all sequences on the dataset

# %%
from kiss_icp_eval import run_sequence


def kitti_sequence(sequence: int):
    return OdometryPipeline(
        dataset=dataset_factory(
            dataloader="kitti",
            data_dir=kitti_root,
            sequence=sequence,
        )
    )


results = {}
for sequence in range(0, 11):
    run_sequence(kitti_sequence, sequence=sequence, results=results)
# Out:
# Now evaluating sequence 00
#   0%|                                                                                   | 0/4541 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.521   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   3.328   m
#   Absolute Rotational Error (ARE)   0.018   rad
#                 Average Frequency    122    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 01
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.716   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   2.859   m
#   Absolute Rotational Error (ARE)   0.016   rad
#                 Average Frequency    61     Hz
#                   Average Runtime    17     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 02
#   0%|                                                                                   | 0/4661 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.503   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   5.967   m
#   Absolute Rotational Error (ARE)   0.023   rad
#                 Average Frequency    104    Hz
#                   Average Runtime    10     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 03
#   0%|                                                                                    | 0/801 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.724   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.526   m
#   Absolute Rotational Error (ARE)   0.009   rad
#                 Average Frequency    75     Hz
#                   Average Runtime    14     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 04
#   0%|                                                                                    | 0/271 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.354   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   0.223   m
#   Absolute Rotational Error (ARE)   0.510   rad
#                 Average Frequency    80     Hz
#                   Average Runtime    13     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 05
#   0%|                                                                                   | 0/2761 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.337   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   1.663   m
#   Absolute Rotational Error (ARE)   0.011   rad
#                 Average Frequency    114    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 06
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.283   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   0.456   m
#   Absolute Rotational Error (ARE)   0.006   rad
#                 Average Frequency    69     Hz
#                   Average Runtime    15     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 07
#   0%|                                                                                   | 0/1101 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.366   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.331   m
#   Absolute Rotational Error (ARE)   0.007   rad
#                 Average Frequency    129    Hz
#                   Average Runtime     8     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 08
#   0%|                                                                                   | 0/4071 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.814   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   2.072   m
#   Absolute Rotational Error (ARE)   0.017   rad
#                 Average Frequency    83     Hz
#                   Average Runtime    12     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 09
#   0%|                                                                                   | 0/1591 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.535   %
#          Average Rotational Error   0.001   deg/m
#   Absolute Trajectory Error (ATE)   1.080   m
#   Absolute Rotational Error (ARE)   0.013   rad
#                 Average Frequency    82     Hz
#                   Average Runtime    13     ms
#  ─────────────────────────────────────────────────
# Now evaluating sequence 10
#   0%|                                                                                   | 0/1201 [00:00<?, ? f…
#  ─────────────────────────────────────────────────
#                            Metric   Value   Units
#  ─────────────────────────────────────────────────
#         Average Translation Error   0.479   %
#          Average Rotational Error   0.002   deg/m
#   Absolute Trajectory Error (ATE)   0.735   m
#   Absolute Rotational Error (ARE)   0.010   rad
#                 Average Frequency    119    Hz
#                   Average Runtime     9     ms
#  ─────────────────────────────────────────────────

# %%
from kiss_icp_eval import print_metrics_table

print_metrics_table(results)
# Out:
# # Experiment Results
# |Metric|Value|Units|
# |-:|:-:|:-|
# Average Translation Error| 0.5121|% |
# Average Rotational Error| 0.0014|deg/m |
# Absolute Trajectory Error (ATE)| 1.7493|m |
# Absolute Rotational Error (ARE)| 0.0582|rad |
# Average Frequency| 94.3636|Hz |
# Average Runtime| 11.7273|ms |

# %% [markdown]
# ## Trajectories Results

# %%
from kiss_icp_eval import plot_trajectories

plot_trajectories(results)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
